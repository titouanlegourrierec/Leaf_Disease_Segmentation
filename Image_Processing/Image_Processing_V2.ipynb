# %%
import PIL
import os
import matplotlib.pyplot as plt
import numpy as np
import cv2
from rembg import remove

PIL.Image.MAX_IMAGE_PIXELS = None #Increase image size limit

# %%
def detect_leaves(input_image):
    """
    Detects and returns bounding boxes around specific areas (leaves) in the input image.
    
    Args:
    input_image (numpy.ndarray): Input image to detect leaves from.
    
    Returns:
    numpy.ndarray: Array containing bounding boxes around leaves.
    """
    # Convert input image to numpy array
    #img = np.array(input_image)
    img = input_image
    
    # Remove Background of input_image
    output_image = np.array(remove(img))

    # Threshold area to filter small contours
    THRESHOLD_AREA = 600000

    # Convert BGR image to RGB
    img = cv2.cvtColor(output_image, cv2.COLOR_BGR2RGB)

    # Define lower and higher bounds for color thresholding
    lower = np.array([5, 10, 5])  # Lower bounds for BGR channels
    higher = np.array([250, 250, 250])

    # Create mask using color thresholding
    mask = cv2.inRange(img, lower, higher)

    # Find contours in the mask
    contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)

    # Initialize list to store detected bounding boxes
    bounding_boxes = []

    # Iterate through contours to filter and extract bounding boxes around leaves
    for contour in contours:
        area = cv2.contourArea(contour)
        if area > THRESHOLD_AREA:
            x, y, w, h = cv2.boundingRect(contour)
            # Filter bounding boxes based on width and height
            if w > 400 and h > 5000:
                bounding_boxes.append([x, y, x+w, y+h])

    # Convert list of bounding boxes to numpy array and return
    return np.array(bounding_boxes)

# %%
def is_image_unusable(image):
    """
    Checks if the image is unusable based on its dimensions.
    
    Args:
    image (numpy.ndarray): Input image to check for usability.
    
    Returns:
    bool: True if the image is unusable, False otherwise.
    """
    # Get the height and width of the image
    height = image.shape[0]
    
    # Define the threshold values for image dimensions as constants
    MIN_HEIGHT = 13000
    MAX_HEIGHT = 22500
    
    # Check if the height is outside the acceptable range
    if height < MIN_HEIGHT or height > MAX_HEIGHT:
        return True
    else:
        return False

# %%
def image_processing(entry_path, exit_path):
    """
    Process images in the specified directory.
    
    Args:
    entry_path (str): Path to the directory containing input images.
    exit_path (str): Path to the directory where processed images will be saved.
    """
    # Initialize counters
    num_files = 0
    count_files = 0
    count_unusable_files = 0
    
    # Count the number of JPEG files in the entry directory
    for filename in os.listdir(entry_path):
        if filename.lower().endswith('.jpg'):
            num_files += 1

    # Create the output directory 'new_results'
    new_results_path = os.path.join(exit_path, "new_results")
    exit_path = new_results_path
    os.makedirs(new_results_path, exist_ok=True)  # This line creates the directory if it doesn't exist
    
    # Create subdirectories 'File' and 'Unusable_File' inside 'new_results'
    file_path = os.path.join(new_results_path, "File")
    unusable_file_path = os.path.join(new_results_path, "Unusable_File")
    os.makedirs(file_path, exist_ok=True)
    os.makedirs(unusable_file_path, exist_ok=True)

    # Process each JPEG file in the entry directory
    for i in range(num_files):
        full_path = os.path.join(entry_path, str(i+1) + ".jpg")
            
        # Read the image
        img = cv2.imread(full_path)
        count_files += 1

        # Check if the image is unusable
        if is_image_unusable(img):
            count_unusable_files += 1
            cv2.imwrite(f"{exit_path}/Unusable_File/Unusable_File_{count_files}.jpg", img)
            continue
        else:
            # Detect leaves and save each leaf as a separate image
            bounding_boxes = detect_leaves(img)
            for j, box in enumerate(bounding_boxes):
                x1, y1, x2, y2 = box
                part = img[y1:y2, x1:x2]

                cv2.imwrite(f"{exit_path}/File/Sheet{count_files}_leaf{j + 1}.jpg", part)

    print(f"Usable Files: {count_files - count_unusable_files}, Unusable Files: {count_unusable_files}")

# %%
image_processing("/Users/titouanlegourrierec/Desktop/all_scan_data/all_090523", "/Users/titouanlegourrierec/Desktop/new_results")
# Out:
# Corrupt JPEG data: 4110 extraneous bytes before marker 0xd5
# 2024-03-28 11:01:58.104875 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4621 extraneous bytes before marker 0xd2
# 2024-03-28 11:02:11.807418 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4541 extraneous bytes before marker 0xd7
# 2024-03-28 11:02:24.295763 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4254 extraneous bytes before marker 0xd6
# 2024-03-28 11:02:37.142820 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4284 extraneous bytes before marker 0xd1
# 2024-03-28 11:02:50.221848 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4336 extraneous bytes before marker 0xd5
# 2024-03-28 11:03:03.320163 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4199 extraneous bytes before marker 0xd3
# 2024-03-28 11:03:16.820857 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4218 extraneous bytes before marker 0xd4
# 2024-03-28 11:03:30.407720 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4311 extraneous bytes before marker 0xd4
# 2024-03-28 11:03:43.456068 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4424 extraneous bytes before marker 0xd3
# 2024-03-28 11:03:56.745664 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4661 extraneous bytes before marker 0xd6
# 2024-03-28 11:04:09.597865 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4183 extraneous bytes before marker 0xd0
# 2024-03-28 11:04:22.624816 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4611 extraneous bytes before marker 0xd4
# 2024-03-28 11:04:35.756337 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4375 extraneous bytes before marker 0xd7
# 2024-03-28 11:04:48.588280 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4452 extraneous bytes before marker 0xd7
# 2024-03-28 11:05:02.005805 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4305 extraneous bytes before marker 0xd3
# 2024-03-28 11:05:14.889591 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4326 extraneous bytes before marker 0xd2
# 2024-03-28 11:05:27.396404 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4405 extraneous bytes before marker 0xd0
# 2024-03-28 11:05:41.000394 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4476 extraneous bytes before marker 0xd5
# 2024-03-28 11:05:53.251791 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4238 extraneous bytes before marker 0xd0
# 2024-03-28 11:06:05.601904 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4158 extraneous bytes before marker 0xd1
# 2024-03-28 11:06:18.204725 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4327 extraneous bytes before marker 0xd1
# 2024-03-28 11:06:31.055398 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4293 extraneous bytes before marker 0xd5
# 2024-03-28 11:06:44.318549 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4719 extraneous bytes before marker 0xd0
# Corrupt JPEG data: 3959 extraneous bytes before marker 0xd6
# Corrupt JPEG data: 4517 extraneous bytes before marker 0xd2
# Corrupt JPEG data: 4296 extraneous bytes before marker 0xd2
# 2024-03-28 11:06:57.648669 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 3859 extraneous bytes before marker 0xd3
# Corrupt JPEG data: 5524 extraneous bytes before marker 0xd4
# Corrupt JPEG data: 5000 extraneous bytes before marker 0xd1
# Corrupt JPEG data: 6552 extraneous bytes before marker 0xd1
# Corrupt JPEG data: 4579 extraneous bytes before marker 0xd0
# 2024-03-28 11:07:10.800380 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 
[W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 3925 extraneous bytes before marker 0xd0
# 2024-03-28 11:30:18.683979 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4641 extraneous bytes before marker 0xd0
# Corrupt JPEG data: 6572 extraneous bytes before marker 0xd0
# Corrupt JPEG data: 4234 extraneous bytes before marker 0xd2
# 2024-03-28 11:30:32.321332 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4075 extraneous bytes before marker 0xd4
# 2024-03-28 11:30:45.538893 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4081 extraneous bytes before marker 0xd7
# 2024-03-28 11:30:58.303167 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4042 extraneous bytes before marker 0xd5
# 2024-03-28 11:31:11.545086 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4444 extraneous bytes before marker 0xd1
# 2024-03-28 11:31:25.308962 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4237 extraneous bytes before marker 0xd4
# 2024-03-28 11:31:39.974232 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4302 extraneous bytes before marker 0xd3
# 2024-03-28 11:31:54.803867 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4078 extraneous bytes before marker 0xd1
# 2024-03-28 11:32:10.601092 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 3882 extraneous bytes before marker 0xd1
# 2024-03-28 11:32:25.064273 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4040 extraneous bytes before marker 0xd0
# 2024-03-28 11:32:38.521853 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4216 extraneous bytes before marker 0xd3
# 2024-03-28 11:32:51.806372 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4520 extraneous bytes before marker 0xd2
# 2024-03-28 11:33:05.350702 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4187 extraneous bytes before marker 0xd6
# 2024-03-28 11:33:19.279427 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4268 extraneous bytes before marker 0xd4
# Corrupt JPEG data: 4241 extraneous bytes before marker 0xd0
# 2024-03-28 11:33:33.531848 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 3921 extraneous bytes before marker 0xd5
# 2024-03-28 11:33:46.240963 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 3918 extraneous bytes before marker 0xd0
# 2024-03-28 11:33:59.770594 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4446 extraneous bytes before marker 0xd0
# 2024-03-28 11:34:13.398198 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4395 extraneous bytes before marker 0xd6
# ...
# Corrupt JPEG data: 4538 extraneous bytes before marker 0xd1
# 2024-03-28 13:10:01.546802 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4766 extraneous bytes before marker 0xd0
# 2024-03-28 13:10:13.928918 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4587 extraneous bytes before marker 0xd5
# 2024-03-28 13:10:27.152568 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4996 extraneous bytes before marker 0xd0
# 2024-03-28 13:10:40.420752 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4665 extraneous bytes before marker 0xd4
# 2024-03-28 13:10:54.305317 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4939 extraneous bytes before marker 0xd6
# 2024-03-28 13:11:07.428057 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4523 extraneous bytes before marker 0xd3
# 2024-03-28 13:11:20.992374 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4616 extraneous bytes before marker 0xd7
# 2024-03-28 13:11:33.608742 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4798 extraneous bytes before marker 0xd4
# 2024-03-28 13:11:46.950523 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4458 extraneous bytes before marker 0xd6
# 2024-03-28 13:12:01.627730 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4798 extraneous bytes before marker 0xd3
# 2024-03-28 13:12:15.587107 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4617 extraneous bytes before marker 0xd6
# Corrupt JPEG data: 6277 extraneous bytes before marker 0xd6
# 2024-03-28 13:12:30.263621 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4715 extraneous bytes before marker 0xd5
# 2024-03-28 13:12:44.131903 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4413 extraneous bytes before marker 0xd2
# 2024-03-28 13:12:57.995133 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4473 extraneous bytes before marker 0xd2
# 2024-03-28 13:13:11.850806 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4598 extraneous bytes before marker 0xd5
# 2024-03-28 13:13:26.575109 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4715 extraneous bytes before marker 0xd5
# 2024-03-28 13:13:40.180462 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4623 extraneous bytes before marker 0xd2
# 2024-03-28 13:13:54.916493 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4798 extraneous bytes before marker 0xd5
# 2024-03-28 13:14:09.194981 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4449 extraneous bytes before marker 0xd3
# 2024-03-28 13:14:23.517423 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4664 extraneous bytes before marker 0xd3
# 2024-03-28 13:14:38.704430 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4724 extraneous bytes before marker 0xd7
# 2024-03-28 13:14:53.060226 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4628 extraneous bytes before marker 0xd6
# 2024-03-28 13:15:07.674904 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4576 extraneous bytes before marker 0xd7
# 2024-03-28 13:15:22.279259 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4738 extraneous bytes before marker 0xd5
# 2024-03-28 13:15:36.429005 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4732 extraneous bytes before marker 0xd0
# 2024-03-28 13:15:50.373252 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4643 extraneous bytes before marker 0xd0
# 2024-03-28 13:16:04.174466 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4693 extraneous bytes before marker 0xd7
# 2024-03-28 13:16:18.235747 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4600 extraneous bytes before marker 0xd0
# 2024-03-28 13:16:33.377430 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4594 extraneous bytes before marker 0xd7
# 2024-03-28 13:16:46.956372 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4949 extraneous bytes before marker 0xd2
# 2024-03-28 13:17:00.754412 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4683 extraneous bytes before marker 0xd4
# 2024-03-28 13:17:14.833736 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4715 extraneous bytes before marker 0xd3
# 2024-03-28 13:17:28.844599 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4716 extraneous bytes before marker 0xd0
# 2024-03-28 13:17:42.373068 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4622 extraneous bytes before marker 0xd5
# 2024-03-28 13:17:57.019388 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4723 extraneous bytes before marker 0xd0
# 2024-03-28 13:18:10.359938 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4564 extraneous bytes before marker 0xd4
# 2024-03-28 13:18:24.145794 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4742 extraneous bytes before marker 0xd1
# 2024-03-28 13:18:38.399606 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4678 extraneous bytes before marker 0xd7
# 2024-03-28 13:18:52.491965 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4607 extraneous bytes before marker 0xd4
# 2024-03-28 13:19:06.755224 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4837 extraneous bytes before marker 0xd3
# 2024-03-28 13:19:22.955299 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4591 extraneous bytes before marker 0xd2
# 2024-03-28 13:19:36.055501 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4834 extraneous bytes before marker 0xd5
# 2024-03-28 13:19:48.942629 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4594 extraneous bytes before marker 0xd2
# 2024-03-28 13:20:01.691133 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 5051 extraneous bytes before marker 0xd0
# 2024-03-28 13:20:15.284452 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4597 extraneous bytes before marker 0xd2
# 2024-03-28 13:20:29.186023 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Corrupt JPEG data: 4504 extraneous bytes before marker 0xd7
# 2024-03-28 13:20:41.911076 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# [ WARN:0@8398.215] global loadsave.cpp:248 findDecoder imread_('/Users/titouanlegourrierec/Desktop/all_scan_data/all_090523/674.jpg'): can't open/read file: check file path/integrity
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 image_processing("/Users/titouanlegourrierec/Desktop/all_scan_data/all_090523", "/Users/titouanlegourrierec/Desktop/new_results")
#
# Cell In[4], line 39, in image_processing(entry_path, exit_path)
#      36 count_files += 1
#      38 # Check if the image is unusable
# ---> 39 if is_image_unusable(img):
#      40     count_unusable_files += 1
#      41     cv2.imwrite(f"{exit_path}/Unusable_File/Unusable_File_{count_files}.jpg", img)
#
# Cell In[3], line 12, in is_image_unusable(image)
#       2 """
#       3 Checks if the image is unusable based on its dimensions.
#       4
#    (...)
#       9 bool: True if the image is unusable, False otherwise.
#      10 """
#      11 # Get the height and width of the image
# ---> 12 height = image.shape[0]
#      14 # Define the threshold values for image dimensions as constants
#      15 MIN_HEIGHT = 14000
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %% [markdown]
# ---
# # Brouillon

# %%
import os

def image_processing(entry_path, exit_path):
    """
    Process images in the specified directory.
    
    Args:
    entry_path (str): Path to the directory containing input images.
    exit_path (str): Path to the directory where processed images will be saved.
    """
    # Initialize counters
    num_files = 0
    count_unusable_files = 0
    
    # Count the number of JPEG files in the entry directory
    for filename in os.listdir(entry_path):
        if filename.lower().endswith('.jpg'):
            num_files += 1

    # Create the output directory 'new_results'
    new_results_path = os.path.join(exit_path, "new_results")
    file_path = os.path.join(new_results_path, "File")
    unusable_file_path = os.path.join(new_results_path, "Unusable_File")
    
    os.makedirs(new_results_path, exist_ok=True)  # This line creates the directory if it doesn't exist
    os.makedirs(file_path, exist_ok=True)
    os.makedirs(unusable_file_path, exist_ok=True)

    # Process each JPEG file in the entry directory
    for filename in os.listdir(entry_path):
        if filename.lower().endswith('.jpg'):
            full_path = os.path.join(entry_path, filename)
            
            # Read the image
            img = cv2.imread(full_path)

            # Check if the image is unusable
            if is_image_unusable(img):
                count_unusable_files += 1
                cv2.imwrite(f"{unusable_file_path}/Unusable_File_{filename}", img)
                continue
            else:
                # Detect leaves and save each leaf as a separate image
                bounding_boxes = detect_leaves(img)
                for j, box in enumerate(bounding_boxes):
                    x1, y1, x2, y2 = box
                    part = img[y1:y2, x1:x2]

                    # Use the input image filename for output file naming
                    output_filename = f"Sheet_{os.path.splitext(filename)[0]}_leaf{j + 1}.jpg"
                    cv2.imwrite(os.path.join(file_path, output_filename), part)

    print(f"Usable Files: {num_files - count_unusable_files}, Unusable Files: {count_unusable_files}")

image_processing("/Users/titouanlegourrierec/Desktop/Test ilastic", "/Users/titouanlegourrierec/Desktop/")
# Out:
# Corrupt JPEG data: 4149 extraneous bytes before marker 0xd3
# 2024-03-24 18:32:28.960115 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Corrupt JPEG data: 4401 extraneous bytes before marker 0xd0
# 2024-03-24 18:32:45.404231 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Corrupt JPEG data: 4389 extraneous bytes before marker 0xd0
# 2024-03-24 18:33:00.990845 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Corrupt JPEG data: 4255 extraneous bytes before marker 0xd1
# 2024-03-24 18:33:17.163987 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Corrupt JPEG data: 4342 extraneous bytes before marker 0xd7
# 2024-03-24 18:33:34.519521 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Corrupt JPEG data: 4077 extraneous bytes before marker 0xd5
# 2024-03-24 18:33:50.327279 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 67 number of nodes in the graph: 371 number of nodes supported by CoreML: 300
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Usable Files: 6, Unusable Files: 0
